# %% [markdown]
# <a href="https://colab.research.google.com/github/SimonDelgado/EIE_401_MULTIMEDIA/blob/main/Actividad_1_DelgadoSimon_202840051.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np

# %%
array = np.linspace(0, 10, 50) # se crea un espacio de 50 elementos donde se evaluarán las funciones
array
# Out:
# array([ 0.        ,  0.20408163,  0.40816327,  0.6122449 ,  0.81632653,
#         1.02040816,  1.2244898 ,  1.42857143,  1.63265306,  1.83673469,
#         2.04081633,  2.24489796,  2.44897959,  2.65306122,  2.85714286,
#         3.06122449,  3.26530612,  3.46938776,  3.67346939,  3.87755102,
#         4.08163265,  4.28571429,  4.48979592,  4.69387755,  4.89795918,
#         5.10204082,  5.30612245,  5.51020408,  5.71428571,  5.91836735,
#         6.12244898,  6.32653061,  6.53061224,  6.73469388,  6.93877551,
#         7.14285714,  7.34693878,  7.55102041,  7.75510204,  7.95918367,
#         8.16326531,  8.36734694,  8.57142857,  8.7755102 ,  8.97959184,
#         9.18367347,  9.3877551 ,  9.59183673,  9.79591837, 10.        ])

# %%
funcion1 = np.exp(-array**2) #función 1 con x=[0, 10]
funcion1
# Out:
# array([1.00000000e+00, 9.59206103e-01, 8.46540486e-01, 6.87396631e-01,
#        5.13559695e-01, 3.53019205e-01, 2.23269602e-01, 1.29922608e-01,
#        6.95606658e-02, 3.42662513e-02, 1.55307822e-02, 6.47655305e-03,
#        2.48495422e-03, 8.77236563e-04, 2.84930489e-04, 8.51500659e-05,
#        2.34128844e-05, 5.92309527e-06, 1.37868923e-06, 2.95262243e-07,
#        5.81799459e-08, 1.05478168e-08, 1.75944505e-09, 2.70030429e-10,
#        3.81305940e-11, 4.95402622e-12, 5.92197948e-13, 6.51327421e-14,
#        6.59106649e-15, 6.13671409e-16, 5.25702393e-17, 4.14350516e-18,
#        3.00482844e-19, 2.00491213e-20, 1.23082093e-21, 6.95213617e-23,
#        3.61297980e-24, 1.72757401e-25, 7.60031617e-27, 3.07645468e-28,
#        1.14575893e-29, 3.92608635e-31, 1.23779952e-32, 3.59058025e-34,
#        9.58302969e-36, 2.35323281e-37, 5.31680613e-39, 1.10525024e-40,
#        2.11394791e-42, 3.72007598e-44])

# %%
def funcion2(z): #función 2, con x e y parametrizados en función de z
  x = z
  y = z
  return y*np.sin(x)

funcion2(array)
# Out:
# array([ 0.        ,  0.0413608 ,  0.16200986,  0.35186084,  0.5948039 ,
#         0.86971589,  1.15179525,  1.41414725,  1.62953058,  1.77216669,
#         1.81950863,  1.75386699,  1.5637967 ,  1.2451602 ,  0.80179828,
#         0.24576023, -0.40293269, -1.1169913 , -1.86300628, -2.60299144,
#        -3.2962518 , -3.9014869 , -4.37902496, -4.69307334, -4.81386712,
#        -4.71959884, -4.39802064, -3.8476234 , -3.07831593, -2.11155061,
#        -0.97986787,  0.27413954,  1.59941271,  2.93850471,  4.23006626,
#         5.41163154,  6.42257852,  7.20712579,  7.71722143,  7.91518027,
#         7.77593345,  7.28876834,  6.45845766,  5.30570257,  3.86684455,
#         2.19283453,  0.34748214, -1.59495741, -3.55276828, -5.44021111])

# %%
import matplotlib.pyplot as plt

# %%
plt.title("Gráfica 1")
plt.plot(array, funcion1) # gráfica función 1
plt.xlabel("Tiempo")
plt.ylabel("Amplitud")
# Out:
# Text(0, 0.5, 'Amplitud')

# %%
plt.title("Gráfica 2")
plt.plot(array, funcion2(array)) #gráfica función 2
plt.xlabel("Tiempo")
plt.ylabel("Amplitud")
# Out:
# Text(0, 0.5, 'Amplitud')

# %%
aleatorio = np.random.random(50) #se crea vector aleatorio para fórmula gaussiana
aleatorio
# Out:
# array([0.51793696, 0.45531455, 0.12692687, 0.16639184, 0.68892002,
#        0.32632921, 0.48946035, 0.76343331, 0.94357057, 0.00305731,
#        0.02447392, 0.45275364, 0.02613898, 0.33817591, 0.67231048,
#        0.71539487, 0.43738738, 0.1820491 , 0.33493592, 0.27779208,
#        0.0845171 , 0.74540642, 0.30309512, 0.32278408, 0.28061289,
#        0.26335623, 0.90678196, 0.3653822 , 0.72466486, 0.46373023,
#        0.84375371, 0.25461737, 0.65511457, 0.57557679, 0.51695197,
#        0.27029462, 0.35053108, 0.84946351, 0.92762803, 0.35999871,
#        0.67801866, 0.3902945 , 0.97562928, 0.03987217, 0.04070266,
#        0.00765629, 0.93802966, 0.38240026, 0.47011318, 0.47452999])

# %%
def gauss(x, mu, sigma): #se genera señal de ruido
  return (1 / (sigma * np.sqrt(2 * np.pi))) * np.exp(-0.5 * (((x - mu) ** 2) / sigma))

gauss(aleatorio, 0, 1) # se presenta una muestra con distribución uniforme de máximo 1
# Out:
# array([0.34886583, 0.3596607 , 0.39574162, 0.39345772, 0.31466587,
#        0.37825606, 0.35390589, 0.29809181, 0.2556103 , 0.39894042,
#        0.39882282, 0.36007913, 0.39880602, 0.37677013, 0.31824326,
#        0.30887042, 0.36255018, 0.39238591, 0.3771812 , 0.38384258,
#        0.39751997, 0.30217351, 0.38103202, 0.37869153, 0.3835404 ,
#        0.38534479, 0.26445999, 0.37318142, 0.30681568, 0.3582725 ,
#        0.27945928, 0.38621791, 0.32189622, 0.33804277, 0.34904368,
#        0.38463205, 0.37517055, 0.27811164, 0.25945152, 0.37391078,
#        0.31701912, 0.36968521, 0.24786655, 0.39862529, 0.39861195,
#        0.39893059, 0.25694625, 0.37081444, 0.35720632, 0.35646191])

# %%
funcion = np.sin(2*array)+np.cos(array) # funcion pura sin ruido agregado
funcion
# Out:
# array([ 1.        ,  1.37617167,  1.6464862 ,  1.75899271,  1.68298992,
#         1.41457734,  0.97797625,  0.4223753 , -0.18521543, -0.76996647,
#        -1.26048581, -1.59952399, -1.75241128, -1.71188079, -1.49852149,
#        -1.1568173 , -0.74744717, -0.33712733,  0.0123275 ,  0.25392765,
#         0.36279612,  0.33964081,  0.20986642,  0.01850403, -0.17817145,
#        -0.32291785, -0.36796512, -0.28385951, -0.06521797,  0.26759044,
#         0.67114559,  1.08564281,  1.44444886,  1.68498873,  1.75917691,
#         1.64167325,  1.33459209,  0.86786843,  0.29519123, -0.31386318,
#        -0.88424493, -1.34672279, -1.64824258, -1.75969213, -1.67983652,
#        -1.43481225, -1.07329281, -0.65814246, -0.25594389,  0.07387372])

# %%
plt.title("Gráfica 3")
plt.plot(array, funcion) #gráfica de función sin ruido
plt.xlabel("Tiempo")
plt.ylabel("Amplitud")
# Out:
# Text(0, 0.5, 'Amplitud')

# %%
funcionruido1 = funcion + gauss(aleatorio, 0, 1)
funcionruido1
# Out:
# array([ 1.34886583,  1.73583237,  2.04222782,  2.15245043,  1.99765579,
#         1.7928334 ,  1.33188214,  0.72046711,  0.07039487, -0.37102606,
#        -0.86166299, -1.23944486, -1.35360526, -1.33511066, -1.18027823,
#        -0.84794688, -0.384897  ,  0.05525858,  0.3895087 ,  0.63777023,
#         0.7603161 ,  0.64181432,  0.59089844,  0.39719556,  0.20536894,
#         0.06242694, -0.10350513,  0.08932191,  0.24159771,  0.62586294,
#         0.95060487,  1.47186072,  1.76634508,  2.0230315 ,  2.10822059,
#         2.02630529,  1.70976264,  1.14598007,  0.55464275,  0.0600476 ,
#        -0.56722581, -0.97703759, -1.40037603, -1.36106684, -1.28122457,
#        -1.03588166, -0.81634655, -0.28732802,  0.10126244,  0.43033563])

# %%
plt.title("Gráfica 4")
plt.plot(array, funcionruido1) # la primera gráfica otorga una deformación leve de la señal
plt.xlabel("Tiempo")
plt.ylabel("Amplitud")
# Out:
# Text(0, 0.5, 'Amplitud')

# %%
funcionruido2 = funcion + gauss(aleatorio, 1, 0.5) # se utilizó la combinación de mu=1 y sigma=0.5 ya que la gráfica otorga una mejor visualización del ruido

# %%
plt.title("Gráfica 5")
plt.plot(array, funcionruido2)
plt.xlabel("Tiempo")
plt.ylabel("Amplitud")
# Out:
# Text(0, 0.5, 'Amplitud')
